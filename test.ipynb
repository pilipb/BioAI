# %%
from layer import *

# %%
point_a = [-121.064088, 38.755719]
point_b = [-121.0610881, 38.752719]
cols = 50

# point a is in red
grid_layers = Grid_Layers(point_a, point_b, cols, buffer_dist=150)

# %%
grid_layers.get_image(plot=True, resolution=1)
# Out:
# 'test_imgs/download.tif'

# %%
grid_layers.river_grid(plot=True, resolution=20)

# %%
grid_layers.tree_grid(plot=True)
# Out:
# Reading config file: /Users/philblecher/opt/miniconda3/envs/deepforest/lib/python3.12/site-packages/deepforest/data/deepforest_config.yml
# GPU available: False, used: False
# No validation file provided. Turning off validation loop
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/philblecher/opt/miniconda3/envs/deepforest/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:75: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
# ---------------------------------------------------------------------------
# ...

# %%
combined_density = grid_layers.combine_layers(1,1)

print('Start index = ', grid_layers.start_index)
print('End index = 'grid_layers.end_index)

plt.figure()
plt.imshow(combined_density, aspect="auto")
plt.show()
